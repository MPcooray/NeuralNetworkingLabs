# %% [markdown]
# <html> <h1 style="font-style:bold; color:blue;"> Neural Computing and Deep Learning </h1> </html>

# %% [markdown]
# <html> <h1 style="font-style:italic; color:blue;"> Week-6 </h1> </html>

# %% [markdown]
# <html> <h2 style="font-style:italic; color:blue;"> RNN for Time Series </h2> </html>
#
#
# RNNs are used for sequence modelling. This tutorial will look at time series data to be modelled and predicted using RNNs.

# %%
# Import Libraries (pandas, numpy, matplotlib)

# ....
# ...
# ...
# Import Libraries (pandas, numpy, matplotlib)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data
#
# We will use retail data for time-series modeling.
#
# Link to the dataset:
#  https://fred.stlouisfed.org/series/MRTSSM448USN
#
# Information about the Advance Monthly Retail Sales Survey can be found on the Census website at:
# https://www.census.gov/retail/marts/about_the_surveys.html
#
# Release: Advance Monthly Sales for Retail and Food Services
# Units:  Millions of Dollars, Not Seasonally Adjusted
# Frequency:  Monthly
#
# Suggested Citation:
# U.S. Census Bureau, Advance Retail Sales: Clothing and Clothing Accessory Stores [RSCCASN], retrieved from FRED, Federal Reserve Bank of St. Louis; https://fred.stlouisfed.org/series/RSCCASN, January 25, 2025.

# %% [markdown]
# ##### Read data first -  Use index_col = 'DATE' and 'parse_dates = True' as a parameter.

# %% [markdown]
# _________________![image.png](attachment:d2f728cb-4c14-4ede-9ca4-3210197b3bf5.png)

# %%
# Read data

df = pd.read_csv('MRTSSM448USN_24.csv', index_col='observation_date', parse_dates=True)

# %%
#pd.read_csv

# %%
# Print the first few rows of data
#d
# ...

df.head()
# Out:
#                   MRTSSM448USN
# observation_date
# 1992-01-01                6938
# 1992-02-01                7524
# 1992-03-01                8475
# 1992-04-01                9401
# 1992-05-01                9558

# %%
# Out:
#                   MRTSSM448USN
# observation_date
# 1992-01-01                6938
# 1992-02-01                7524
# 1992-03-01                8475
# 1992-04-01                9401
# 1992-05-01                9558

# %% [markdown]
# _______________![image.png](attachment:7e472928-25f6-4701-891d-d6e138d8301c.png)

# %%
df.tail()
# Out:
#                   MRTSSM448USN
# observation_date
# 2024-08-01               27215
# 2024-09-01               23088
# 2024-10-01               25318
# 2024-11-01               29762
# 2024-12-01               41199

# %%
# Out:
#                   MRTSSM448USN
# observation_date
# 2024-08-01               27215
# 2024-09-01               23088
# 2024-10-01               25318
# 2024-11-01               29762
# 2024-12-01               41199

# %% [markdown]
# Does the sales column has any name?
#
# If no, set the name of the colum as 'Sales'.

# %%
# Set name of column as 'Sales'. Use - df.columns 

# ...
# Set name of column as 'Sales'. Use - df.columns

df.columns = ['Sales']
df.head()
# Out:
#                   Sales
# observation_date
# 1992-01-01         6938
# 1992-02-01         7524
# 1992-03-01         8475
# 1992-04-01         9401
# 1992-05-01         9558

# %%
# Out:
#                   Sales
# observation_date
# 1992-01-01         6938
# 1992-02-01         7524
# 1992-03-01         8475
# 1992-04-01         9401
# 1992-05-01         9558

# %% [markdown]
# Plot your data - Year vs Sales
#
# hint: use df.plot  and plt.show()

# %% [markdown]
# ____________![image.png](attachment:805024e0-d954-465a-b7e2-ddfb909885ff.png)

# %%
# Plot Year vs Sales

df.plot(figsize=(12,8))

plt.show()

# %% [markdown]
# ### Train Test Split
#
# We will use the last 1.5 years (18 months) samples for testing. The rest is for training

# %% [markdown]
# ______________![image.png](attachment:e38848db-d649-4cf7-a213-65b7f4afb347.png)

# %%
# Assign variable test size = 18

test_size = 18
test_size
# Out:
# 18

# %%
# Out:
# 18

# %% [markdown]
# __________![image.png](attachment:2c857cf3-2515-4517-9d3d-db350c691bf7.png)

# %%
# Store length of data in variable Length.

data_length = len(df)
data_length
# Out:
# 396

# %%
# Out:
# 396

# %% [markdown]
# __________________![image.png](attachment:f8eaa367-9088-41f8-8b8b-9d268a0818ed.png)

# %%
train_size = data_length - test_size
train_size
# Out:
# 378

# %%
# Out:
# 378

# %% [markdown]
# Now, we will find the indexes of the test data. Remember, these are the last 18 indexes in the pandas dataframe.

# %% [markdown]
# ____________________![image.png](attachment:91a08444-364a-40fa-a0c3-839197c15995.png)

# %%
test_index = train_size
test_index
# Out:
# 378

# %%
# Out:
# 378

# %% [markdown]
# Next, we will separate train and test datasets.

# %% [markdown]
# _________________________![image.png](attachment:3ae07221-155f-4716-9ea4-7484eb94dab4.png)

# %%
train = df.iloc[:test_index]
train
# Out:
#                   Sales
# observation_date
# 1992-01-01         6938
# 1992-02-01         7524
# 1992-03-01         8475
# 1992-04-01         9401
# 1992-05-01         9558
# ...                 ...
# 2023-02-01        20666
# 2023-03-01        24510
# 2023-04-01        24232
# 2023-05-01        26096
# 2023-06-01        24364
#
# [378 rows x 1 columns]

# %%
# Out:
#                   Sales
# observation_date
# 1992-01-01         6938
# 1992-02-01         7524
# 1992-03-01         8475
# 1992-04-01         9401
# 1992-05-01         9558
# ...                 ...
# 2023-02-01        20666
# 2023-03-01        24510
# 2023-04-01        24232
# 2023-05-01        26096
# 2023-06-01        24364
#
# [378 rows x 1 columns]

# %%
# Store everything from test_index to the last sample in the test variable 
# Hint - Use df.iloc

# ...
# ...
test = df.iloc[test_index:]
test
# Out:
#                   Sales
# observation_date
# 2023-07-01        24911
# 2023-08-01        26657
# 2023-09-01        23332
# 2023-10-01        23933
# 2023-11-01        28580
# 2023-12-01        40684
# 2024-01-01        19188
# 2024-02-01        22005
# 2024-03-01        24986
# 2024-04-01        23993
# 2024-05-01        27562
# 2024-06-01        25121
# 2024-07-01        25453
# 2024-08-01        27215
# 2024-09-01        23088
# 2024-10-01        25318
# 2024-11-01        29762
# 2024-12-01        41199

# %%
# Out:
#                   Sales
# observation_date
# 2023-07-01        24911
# 2023-08-01        26657
# 2023-09-01        23332
# 2023-10-01        23933
# 2023-11-01        28580
# 2023-12-01        40684
# 2024-01-01        19188
# 2024-02-01        22005
# 2024-03-01        24986
# 2024-04-01        23993
# 2024-05-01        27562
# 2024-06-01        25121
# 2024-07-01        25453
# 2024-08-01        27215
# 2024-09-01        23088
# 2024-10-01        25318
# 2024-11-01        29762
# 2024-12-01        41199

# %%
# Print the size of the train data
len(train)
# Out:
# 378

# %%
# Print the size of the test data
len(test)
# Out:
# 18

# %%
# Out:
# 378
# 18

# %% [markdown]
# ### In Neural Networks, we need to Scale Data between 0-1

# %% [markdown]
# ___________________![image.png](attachment:427170b6-570a-4740-b005-cd2e88a0f8b6.png)

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# _______________________![image.png](attachment:b5ef2c4e-c013-4af5-9320-c48c58751458.png)

# %%
scaler = MinMaxScaler()
scaler.fit(train)
# Out:
# MinMaxScaler()

# %%
# Out:
# MinMaxScaler()

# %% [markdown]
# __________________![image.png](attachment:4e64d75b-6582-4975-bd2f-3881d943301d.png)

# %%
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
# Check if the data has been scaled properly
# Print max and min for train and test

# ...
# ...
# ...
# ...

print(scaled_train.max())
print(scaled_test.max())
print(scaled_train.min())
print(scaled_test.min())
# Out:
# 1.0
# 1.0530599939704552
# 0.0
# 0.44980403979499545

# %%
# Out:
# 1.0
# 1.0530599939704552
# 0.0
# 0.44980403979499545

# %% [markdown]
# ## Time Series Generator
#
# This class takes in a sequence of data points gathered at
# equal intervals, along with time series parameters such as
# stride, length of history, etc., to produce batches for
# training/validation.
#
# #### Arguments
#     data: Indexable generator (such as list or Numpy array)
#         containing consecutive data points (timesteps).
#         The data should be at 2D, and axis 0 is expected
#         to be the time dimension.
#     targets: Targets corresponding to timesteps in `data`.
#         It should have same length as `data`.
#     length: Length of the output sequences (in number of timesteps).
#     sampling_rate: Period between successive individual timesteps
#         within sequences. For rate `r`, timesteps
#         `data[i]`, `data[i-r]`, ... `data[i - length]`
#         are used for create a sample sequence.
#     stride: Period between successive output sequences.
#         For stride `s`, consecutive output samples would
#         be centered around `data[i]`, `data[i+s]`, `data[i+2*s]`, etc.
#     start_index: Data points earlier than `start_index` will not be used
#         in the output sequences. This is useful to reserve part of the
#         data for test or validation.
#     end_index: Data points later than `end_index` will not be used
#         in the output sequences. This is useful to reserve part of the
#         data for test or validation.
#     shuffle: Whether to shuffle output samples,
#         or instead draw them in chronological order.
#     reverse: Boolean: if `true`, timesteps in each output sample will be
#         in reverse chronological order.
#     batch_size: Number of timeseries samples in each batch
#         (except maybe the last one).

# %% [markdown]
# ### We will use 12 months as input and then predict the next month out

# %% [markdown]
# _____________________![image.png](attachment:75eeec67-065a-4084-9a2b-c10207e20cba.png)

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
print(scaled_train.shape)
print(type(scaled_train))
# Out:
# (378, 1)
# <class 'numpy.ndarray'>

# %%
#TimeseriesGenerator?

# %% [markdown]
# _________________![image.png](attachment:280feffa-2228-4562-9b29-005f579078ef.png)

# %%
# Let's redefine to get 12 months back and then predict the next month out

length = 12
generator = TimeseriesGenerator(scaled_train, scaled_train,
                                length=length, batch_size=1)

# %% [markdown]
# _______________________![image.png](attachment:6525f6be-465f-4f4c-8198-cad63a006c9b.png)

# %%
# What does the first batch look like?

X, y = generator[0]

print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.11406802 0.13012854 0.15619262 0.18157152 0.18587442 0.17556938
#  0.17340423 0.21204813 0.18628553 0.20494971 0.23052046 0.42807027]
# Predict this y:
#  [[0.12952558]]

# %%
# Out:
# Given the Array:
# [0.11406802 0.13012854 0.15619262 0.18157152 0.18587442 0.17556938
#  0.17340423 0.21204813 0.18628553 0.20494971 0.23052046 0.42807027]
# Predict this y:
#  [[0.12952558]]

# %% [markdown]
# ### Create the Model

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.layers import GRU

import tensorflow as tf

# %% [markdown]
# ________________![image.png](attachment:aef51a9d-f017-45c3-a12d-2a77630a3721.png)

# %%
n_features = 1
n_features
# Out:
# 1

# %%
# Out:
# 1

# %% [markdown]
# ## Define your own models.
#
# Use 1. SimpleRNN, LSTM, or GRU neural network.
#
# APIs:
# https://keras.io/api/layers/recurrent_layers/

# %%
# Your code to create your own model
# use input_shape=(length, n_features)
# use model.add(Dense(1)) because it is the regression task
 
# .....
# .....
# .....
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model = Sequential()

model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

model.summary()
# Out:
# /opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100)            │        40,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,901 (159.77 KB)
#  Trainable params: 40,901 (159.77 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100)            │        40,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,901 (159.77 KB)
#  Trainable params: 40,901 (159.77 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# _____________________![image.png](attachment:5f040382-1621-443b-87a6-48ad7c9c995f.png)

# %%
model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# ### EarlyStopping and creating a Validation Generator
#
# NOTE: The scaled_test dataset size MUST be greater than your length chosen for your batches.
#
# Review the video on the Week-6 page for more info on this.

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the 2 next cells using 'Ctrl' + 'Enter' </h4> </html>

# %%
validation_generator = TimeseriesGenerator(scaled_test, scaled_test, 
                                           length=length, batch_size=1)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Your code to create an object early-stop

# Use the patience parameter equal to the last digit in your SID.
# If the last digit of your SID = 0, then assign patience=10
# For example, your SID = 22984879, then patience=9

# LAST_DIGIT_IN_YOUR_SID = 

from tensorflow.keras.callbacks import EarlyStopping

LAST_DIGIT_IN_YOUR_SID = 2

early_stop = EarlyStopping(monitor='val_loss', patience=LAST_DIGIT_IN_YOUR_SID)

# %% [markdown]
# _____________________![image.png](attachment:e0ecd664-7df5-4386-a700-adb2228bf254.png)

# %%
# Fit your model.
# IGNORE THE WARNING

history = model.fit(generator, epochs=30,
                    validation_data=validation_generator,
                    )
# Out:
# Epoch 1/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0044 - val_loss: 0.0100
# Epoch 2/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0045 - val_loss: 0.0037
# Epoch 3/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0050 - val_loss: 7.2264e-04
# Epoch 4/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0038 - val_loss: 0.0029
# Epoch 5/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0037 - val_loss: 5.4526e-04
# Epoch 6/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0034 - val_loss: 0.0019
# Epoch 7/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0032 - val_loss: 5.1096e-04
# Epoch 8/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0027 - val_loss: 0.0015
# Epoch 9/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0028 - val_loss: 8.4495e-04
# Epoch 10/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0028 - val_loss: 5.8461e-04
# Epoch 11/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0027 - val_loss: 7.8946e-04
# Epoch 12/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0025 - val_loss: 0.0058
# Epoch 13/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 14/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0022 - val_loss: 0.0070
# Epoch 15/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0028 - val_loss: 0.0012
# Epoch 16/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0023 - val_loss: 0.0043
# Epoch 17/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 7.4863e-04
# Epoch 18/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 19/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 9.7433e-04
# Epoch 20/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 21/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 22/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 23/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 24/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 25/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - val_loss: 6.1567e-04
# Epoch 26/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 27/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017 - val_loss: 0.0040
# Epoch 28/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 29/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 30/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0015 - val_loss: 0.0034

# %%
# Out:
# C:\Users\vital\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 0.0364 - val_loss: 0.0283
# Epoch 2/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0124 - val_loss: 0.0153
# Epoch 3/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0118 - val_loss: 0.0010
# Epoch 4/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 0.0068 - val_loss: 0.0032
# Epoch 5/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0047 - val_loss: 0.0127
# Epoch 6/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 0.0079 - val_loss: 0.0011
# Epoch 7/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 8/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 9/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0046 - val_loss: 0.0026
# Epoch 10/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0042 - val_loss: 6.1039e-04
# Epoch 11/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0049 - val_loss: 6.4973e-04
# Epoch 12/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0033 - val_loss: 6.5717e-04
# Epoch 13/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0031 - val_loss: 0.0065
# Epoch 14/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0042 - val_loss: 0.0013
# Epoch 15/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0040 - val_loss: 0.0025
# Epoch 16/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 17/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0026 - val_loss: 8.7657e-04
# Epoch 18/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0045 - val_loss: 8.2289e-04

# %% [markdown]
# _____________![image.png](attachment:00bc3c6b-8d83-4d5c-80cc-1f586fc18bb3.png)

# %%
# Get Losses from the dataframe

losses = pd.DataFrame(model.history.history)
losses[:5]
# Out:
#        loss  val_loss
# 0  0.004424  0.009959
# 1  0.004487  0.003730
# 2  0.004970  0.000723
# 3  0.003805  0.002928
# 4  0.003694  0.000545

# %%
# the values may be different
# Out:
#        loss  val_loss
# 0  0.020090  0.028262
# 1  0.012648  0.015266
# 2  0.010198  0.001036
# 3  0.006880  0.003225
# 4  0.005237  0.012703

# %% [markdown]
# ___________________![image.png](attachment:f4e5651a-8770-46d6-80cd-ad7c715e6fe4.png)

# %%
losses.plot()
plt.show();

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
# print Loss for the neural network training process

history_dict = history.history

acc_values = history_dict['loss']
val_acc_values = history_dict['val_loss']
epochs = range(1, len(acc_values) + 1)

plt.figure(num=1, figsize=(15,7))
plt.plot(epochs, acc_values, 'bo', label='Training loss')
plt.plot(epochs, val_acc_values, 'b', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (mse)')
plt.legend()

plt.show()

# %% [markdown]
# ### Evaluate on Test Data

# %% [markdown]
# ____________________![image.png](attachment:78ee4976-41bd-457c-8de2-ee2446e02523.png)

# %%
print(scaled_train[-15:])
# Out:
# [[0.61523282]
#  [0.64077617]
#  [0.5909502 ]
#  [0.59621235]
#  [0.62693562]
#  [0.55844547]
#  [0.58834653]
#  [0.69254803]
#  [1.        ]
#  [0.44788555]
#  [0.49031162]
#  [0.59566421]
#  [0.58804506]
#  [0.63913175]
#  [0.59166278]]

# %%
# Out:
# [[0.61523282]
#  [0.64077617]
#  [0.5909502 ]
#  [0.59621235]
#  [0.62693562]
#  [0.55844547]
#  [0.58834653]
#  [0.69254803]
#  [1.        ]
#  [0.44788555]
#  [0.49031162]
#  [0.59566421]
#  [0.58804506]
#  [0.63913175]
#  [0.59166278]]

# %% [markdown]
# ____________________![image.png](attachment:7c5efeb5-4631-462d-b593-f7ee0b22b63b.png)

# %%
first_eval_batch = scaled_train[-length:]
first_eval_batch
# Out:
# array([[0.59621235],
#        [0.62693562],
#        [0.55844547],
#        [0.58834653],
#        [0.69254803],
#        [1.        ],
#        [0.44788555],
#        [0.49031162],
#        [0.59566421],
#        [0.58804506],
#        [0.63913175],
#        [0.59166278]])

# %%
# Out:
# array([[0.59621235],
#        [0.62693562],
#        [0.55844547],
#        [0.58834653],
#        [0.69254803],
#        [1.        ],
#        [0.44788555],
#        [0.49031162],
#        [0.59566421],
#        [0.58804506],
#        [0.63913175],
#        [0.59166278]])

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
n_input = 12
first_eval_batch = first_eval_batch.reshape((1, n_input, n_features))
first_eval_batch
# Out:
# array([[[0.59621235],
#         [0.62693562],
#         [0.55844547],
#         [0.58834653],
#         [0.69254803],
#         [1.        ],
#         [0.44788555],
#         [0.49031162],
#         [0.59566421],
#         [0.58804506],
#         [0.63913175],
#         [0.59166278]]])

# %% [markdown]
# ___________________![image.png](attachment:a2b037af-2ff0-42ce-9234-7ee8a9abb742.png)

# %%
model.predict(first_eval_batch)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# array([[0.647917]], dtype=float32)

# %%
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 802ms/step
# array([[0.63285655]], dtype=float32)

# %% [markdown]
# _________________![image.png](attachment:b5adbbdd-43ed-4ee2-9417-382a709986b5.png)

# %%
scaled_test[0]
# Out:
# array([0.60665442])

# %%
# Out:
# array([0.60665442])

# %% [markdown]
# #### Try predicting the series!

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the 3 next cells using 'Ctrl' + 'Enter' </h4> </html>

# %%
test_predictions = []

first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

current_batch
# Out:
# array([[[0.59621235],
#         [0.62693562],
#         [0.55844547],
#         [0.58834653],
#         [0.69254803],
#         [1.        ],
#         [0.44788555],
#         [0.49031162],
#         [0.59566421],
#         [0.58804506],
#         [0.63913175],
#         [0.59166278]]])

# %%
for i in range(len(test)):
    
    # get prediction 1 time stamp ahead ([0] is for 
    # grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    test_predictions.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
test_predictions
# Out:
# [array([0.647917], dtype=float32),
#  array([0.70575416], dtype=float32),
#  array([0.6652281], dtype=float32),
#  array([0.6823154], dtype=float32),
#  array([0.7959813], dtype=float32),
#  array([1.1538147], dtype=float32),
#  array([0.5140643], dtype=float32),
#  array([0.5826964], dtype=float32),
#  array([0.6883803], dtype=float32),
#  array([0.72453237], dtype=float32),
#  array([0.7718863], dtype=float32),
#  array([0.7553659], dtype=float32),
#  array([0.77563894], dtype=float32),
#  array([0.83545727], dtype=float32),
#  array([0.8121254], dtype=float32),
#  array([0.820021], dtype=float32),
#  array([0.94128025], dtype=float32),
#  array([1.2898312], dtype=float32)]

# %% [markdown]
# ### Inverse Transformations and Compare

# %% [markdown]
# _________________![image.png](attachment:9266da43-7b93-47a6-b135-724c546cf46b.png)

# %%
# Undo the scaling

true_predictions = scaler.inverse_transform(test_predictions)
true_predictions
# Out:
# array([[26416.54658061],
#        [28526.85206807],
#        [27048.17872214],
#        [27671.64233488],
#        [31818.96925366],
#        [44875.23598921],
#        [21532.66455126],
#        [24036.84275252],
#        [27892.93204254],
#        [29212.01243091],
#        [30939.81503111],
#        [30337.03589052],
#        [31076.73792899],
#        [33259.32924181],
#        [32408.01891547],
#        [32696.10526675],
#        [37120.49232781],
#        [49838.06958961]])

# %%
# Out:
# array([[25867.03686076],
#        [26708.37140393],
#        [25016.20063967],
#        [25854.56223851],
#        [29340.47320271],
#        [40268.42497611],
#        [20830.97139931],
#        [22252.6564256 ],
#        [25053.23304337],
#        [25580.6207518 ],
#        [27142.1950959 ],
#        [26136.75054663],
#        [27203.31552541],
#        [27836.48089719],
#        [26630.20928335],
#        [27364.5308798 ],
#        [30701.01822633],
#        [41377.06135786]])

# %% [markdown]
# _____________![image.png](attachment:1689e362-0bac-4c6c-a993-55ff6789ceb7.png)

# %%
test['Predictions'] = true_predictions
# Out:
# /var/folders/j2/vk45mvg51yn_gc06s08g59500000gn/T/ipykernel_30104/1950671339.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions

# %%
# Out:
# C:\Users\vital\AppData\Local\Temp\ipykernel_18288\3095654106.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions

# %% [markdown]
# ### Check and plot predictions

# %%
# Print the test variable

# ...
test
# Out:
#                   Sales   Predictions
# observation_date
# 2023-07-01        24911  26416.546581
# 2023-08-01        26657  28526.852068
# 2023-09-01        23332  27048.178722
# 2023-10-01        23933  27671.642335
# 2023-11-01        28580  31818.969254
# 2023-12-01        40684  44875.235989
# 2024-01-01        19188  21532.664551
# 2024-02-01        22005  24036.842753
# 2024-03-01        24986  27892.932043
# 2024-04-01        23993  29212.012431
# 2024-05-01        27562  30939.815031
# 2024-06-01        25121  30337.035891
# 2024-07-01        25453  31076.737929
# 2024-08-01        27215  33259.329242
# 2024-09-01        23088  32408.018915
# 2024-10-01        25318  32696.105267
# 2024-11-01        29762  37120.492328
# 2024-12-01        41199  49838.069590

# %%
# Out:
#                   Sales   Predictions
# observation_date
# 2023-07-01        24911  25867.036861
# 2023-08-01        26657  26708.371404
# 2023-09-01        23332  25016.200640
# 2023-10-01        23933  25854.562239
# 2023-11-01        28580  29340.473203
# 2023-12-01        40684  40268.424976
# 2024-01-01        19188  20830.971399
# 2024-02-01        22005  22252.656426
# 2024-03-01        24986  25053.233043
# 2024-04-01        23993  25580.620752
# 2024-05-01        27562  27142.195096
# 2024-06-01        25121  26136.750547
# 2024-07-01        25453  27203.315525
# 2024-08-01        27215  27836.480897
# 2024-09-01        23088  26630.209283
# 2024-10-01        25318  27364.530880
# 2024-11-01        29762  30701.018226
# 2024-12-01        41199  41377.061358

# %% [markdown]
# _______________![image.png](attachment:f62685ae-fe3d-45e4-b14c-32c3f876ee6c.png)

# %%
test.plot(figsize=(8,5))
plt.show()

# %% [markdown]
# ### Retrain and Forecasting

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the 3 next cells using 'Ctrl' + 'Enter' </h4> </html>

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(df)

# %%
print(scaled_full_data.max())
print(scaled_full_data.min())
# Out:
# 1.0
# 0.0

# %%
length = 12 # Length of the output sequences (in number of timesteps)
generator = TimeseriesGenerator(scaled_full_data, 
                                scaled_full_data, length=length, batch_size=1)

# %%
# Use any neural network model based on RNN
# You can also use the model created above
#
# Create the model

# ...
# ...
# ...
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# Create the model
model = Sequential()

model.add(SimpleRNN(100, activation='relu', input_shape=(length, n_features)))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

model.summary()
# Out:
# /opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Out:
# C:\Users\vital\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# your code to compile the model

# ...

# %%
model.compile(optimizer='adam', loss='mse')

# %%
# Your code to create an object early-stop

# Use the patience parameter equal to the last digit in your SID.
# If the last digit of your SID = 0, then assign patience=10
# For example, your SID = 22984879, then patience=9

# LAST_DIGIT_IN_YOUR_SID = 

early_stop = EarlyStopping(monitor='val_loss',patience=2)

# %% [markdown]
# ____________________![image.png](attachment:7b5b9107-f77e-4327-a987-878819f2ce45.png)

# %%
# fit the model

history_2 =  model.fit(generator,  epochs=30,
                    validation_data=validation_generator,
                    )
# Out:
# Epoch 1/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0175 - val_loss: 0.0653
# Epoch 2/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - loss: 0.0149 - val_loss: 0.0435
# Epoch 3/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 0.0083 - val_loss: 0.0054
# Epoch 4/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 0.0048 - val_loss: 0.0042
# Epoch 5/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - loss: 0.0044 - val_loss: 0.0011
# Epoch 6/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 0.0026 - val_loss: 4.8052e-04
# Epoch 7/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - loss: 0.0025 - val_loss: 0.0010
# Epoch 8/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.0020 - val_loss: 0.0058
# Epoch 9/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 10/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 0.0021 - val_loss: 0.0043
# Epoch 11/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 12/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 13/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 0.0015 - val_loss: 7.3006e-04
# Epoch 14/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 0.0016 - val_loss: 6.4872e-04
# Epoch 15/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.0016 - val_loss: 0.0066
# Epoch 16/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.0033 - val_loss: 0.0023
# Epoch 17/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 0.0014 - val_loss: 4.7949e-04
# Epoch 18/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 19/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 0.0011 - val_loss: 1.4464e-04
# Epoch 20/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 21/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 22/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 23/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 0.0020 - val_loss: 7.3998e-04
# Epoch 24/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 25/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 26/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 0.0018 - val_loss: 0.0077
# Epoch 27/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 0.0012 - val_loss: 6.4155e-04
# Epoch 28/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 29/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 0.0012 - val_loss: 2.8498e-04
# Epoch 30/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - val_loss: 8.6867e-04

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
# print Loss for the neural network training process

history_dict = history_2.history

acc_values = history_dict['loss']
val_acc_values = history_dict['val_loss']
epochs = range(1, len(acc_values) + 1)

plt.figure(num=1, figsize=(15,7))
plt.plot(epochs, acc_values, 'bo', label='Training loss')
plt.plot(epochs, val_acc_values, 'b', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (mse)')
plt.legend()

plt.show()

# %%
# You can use the code created above to type the next cell code

# %% [markdown]
# _________________![image.png](attachment:02c09230-3aba-4573-8e73-6abd5e03c12a.png)

# %%
forecast = []
# Replace periods with whatever forecast length you want
periods = 12

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):

    # get prediction 1 time stamp ahead ([0] is for
    # grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]

    # store prediction
    forecast.append(current_pred)

    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:], [[current_pred]], axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step

# %% [markdown]
# ______________________![image.png](attachment:3072f528-93a6-486e-b230-a376ae174ea2.png)

# %%
forecast = scaler.inverse_transform(forecast)
forecast
# Out:
# array([[18054.67201447],
#        [21150.68361473],
#        [22556.54918456],
#        [21293.55240124],
#        [23178.88842845],
#        [20679.20770258],
#        [21339.62542641],
#        [22600.45176464],
#        [20761.8455506 ],
#        [21549.31695408],
#        [25284.57030243],
#        [34328.28214514]])

# %%
# Out:
# array([[18620.61448288],
#        [20206.91406763],
#        [22167.73939276],
#        [21757.40348327],
#        [23828.92585731],
#        [22448.01823115],
#        [22479.73978627],
#        [23555.70857722],
#        [21352.45454019],
#        [22294.99097872],
#        [25707.46347636],
#        [37294.23667431]])

# %% [markdown]
# ### Creating new timestamp index with pandas.

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the 4 next cells using 'Ctrl' + 'Enter' </h4> </html>

# %%
df
# Out:
#                   Sales
# observation_date
# 1992-01-01         6938
# 1992-02-01         7524
# 1992-03-01         8475
# 1992-04-01         9401
# 1992-05-01         9558
# ...                 ...
# 2024-08-01        27215
# 2024-09-01        23088
# 2024-10-01        25318
# 2024-11-01        29762
# 2024-12-01        41199
#
# [396 rows x 1 columns]

# %%
forecast_index = pd.date_range(start='2025-01-01',periods=periods,freq='MS')

# %%
forecast_df = pd.DataFrame(data=forecast,index=forecast_index,
                           columns=['Forecast'])

# %%
forecast_df
# Out:
#                 Forecast
# 2025-01-01  18054.672014
# 2025-02-01  21150.683615
# 2025-03-01  22556.549185
# 2025-04-01  21293.552401
# 2025-05-01  23178.888428
# 2025-06-01  20679.207703
# 2025-07-01  21339.625426
# 2025-08-01  22600.451765
# 2025-09-01  20761.845551
# 2025-10-01  21549.316954
# 2025-11-01  25284.570302
# 2025-12-01  34328.282145

# %% [markdown]
# __________________![image.png](attachment:a493f4a8-33ea-440d-ad45-8d5a273f8dfb.png)

# %%
# Plot sales - Values in dataframe

df.plot(figsize=(8,5))
plt.show();

# %% [markdown]
# ____________________![image.png](attachment:f61a4158-30b1-457d-9aaa-2945b1ec8833.png)

# %%
# Plot forecast - Values in forecast_df

forecast_df.plot(figsize=(8,5))
plt.show();

# %% [markdown]
# ### Joining pandas plots
#
# https://stackoverflow.com/questions/13872533/plot-different-dataframes-in-the-same-figure

# %% [markdown]
# ________________________![image.png](attachment:1ad9f420-c284-4442-8931-039f36b4390a.png)

# %%
ax = df.plot(figsize=(13,8))
forecast_df.plot(ax=ax)
plt.show();

# %% [markdown]
# _______![image.png](attachment:5611350d-0e2b-4867-9b54-de812a2abd8a.png)

# %%
ax = df.plot(figsize=(8,5))
forecast_df.plot(ax=ax)
plt.xlim('2023-01-01', '2026-01-01')
plt.show();

# %% [markdown]
# ### Cecking Forecast for last 12 months

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the 3 next cells using 'Ctrl' + 'Enter' </h4> </html>

# %%
forecast_index = pd.date_range(start='2024-01-01', periods=periods, freq='MS')
forecast_index
# Out:
# DatetimeIndex(['2024-01-01', '2024-02-01', '2024-03-01', '2024-04-01',
#                '2024-05-01', '2024-06-01', '2024-07-01', '2024-08-01',
#                '2024-09-01', '2024-10-01', '2024-11-01', '2024-12-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
forecast_df = pd.DataFrame(data=forecast, index=forecast_index,
                           columns=['Forecast'])

# %%
ax = df.plot(figsize=(12,6))
forecast_df.plot(ax=ax)
plt.xlim('2020-01-01','2025-01-01')
plt.show();

# %% [markdown]
# <html> <h2 style="font-style:bold; color:red;"> Lab Logbook requirements </h2> </html>
#
# ### 1. Plot of the 2nd model's summary
#
# ### 2. Copy your early-stop code and history_2 fit-training-process
#
# ### 3. Please record the plot of validation and test loss of history_2.
#
# ### 4. Based on this analysis, determine the optimal number of epochs for training your model.

# %% [markdown]
# ### Try the same example with a LSTM and GRU! (Optional)
# Hint: Use LSTM instead of SimpleRNN!
